# %% [markdown]
# # Your Details

# %% [markdown]
# Your Name:

# %% [markdown]
# Your ID Number:

# %% [markdown]
# # Etivity Task 4 - Part 1: Pruning a TensorFlow/Keras Model exercise
#
# For this exercise, you will prune a simple convolutional neural network (CNN) trained on the Fashion MNIST dataset. The first section of this exercise is already completed (Parts 1-5). Your task is to perform pruning on this model uses the TF Model optimisations toolkit and report on the results.
#
#
# By the end of this notebook, you'll be able to:
#
# * Understand Pruning in TensorFlow
# * Prune a basic CNN using the TensorFlow Model optimisation framework
# * Analyse the model perfromance
# * Results analysis
#
# ### Let's get started!
# **Start** with the design in sections [1], [2], [3], [4] and [5] for which code is provided - then proceed to section [6] to begin this model pruning exercise.
#
#     [1] Import data dependencies
#     [2] Load the Fashion MNIST dataset
#     [3] Prepocess the data
#     [4] Create and train the CNN model
#     [5] Evaluate the model performance
#     [6] Prune the network and analyse your results
#
#
# ### Important Note on Submission
#
# There are code exercises to complete in this task.  Insert your code entries into the cell areas marked with the 'enter code here' text as below, so that grading can easily be assessed.
#
# \### **ENTER CODE HERE**
#
# Please make sure you are not doing the following:
#
# 1. You have not added any _extra_ `print` statement(s) in the assignment.
# 2. You have not added any _extra_ code cell(s) in the assignment.
# 3. You have not changed any of the function parameters.
# 4. You are not using any global variables inside your graded exercises. Unless specifically instructed to do so, please refrain from it and use the local variables instead.
# 5. You are not changing the assignment code where it is not required, like creating _extra_ variables.

# %% [markdown]
# ### Installing the TensorFlow Model Optimisation toolkit
#
# You must first install it using pip (comment this out once you have done this).

# %%
#pip install --user --upgrade tensorflow-model-optimization

# %% [markdown]
# ## 1. Import the data dependencies

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import tensorflow_model_optimization as tfmot

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report 

import numpy as np
import pandas as pd
import tempfile

from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 2. Load the dataset
# We will use the Fashion-MNIST dataset and view a random set of images from the dataset.

# %%
# Load Fashion MNIST dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# Create a dictionary of all classes in the target - Note there are 10 classes in this dataset.

# %%
# Map for human readable class names
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
class_labels = pd.Series(['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Code', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle Boot'])
labels_dict = class_labels.to_dict()
labels_dict
# Out:
# {0: 'T-shirt',
#  1: 'Trouser',
#  2: 'Pullover',
#  3: 'Dress',
#  4: 'Code',
#  5: 'Sandal',
#  6: 'Shirt',
#  7: 'Sneaker',
#  8: 'Bag',
#  9: 'Ankle Boot'}

# %% [markdown]
# Get 9 images at random from the training data, plot and fetch their corresponding labels from the training targets.

# %%
np.random.seed(11)
plt.figure(figsize=(10, 10))
for i, rand_num in enumerate(np.random.randint(0, len(X_train), 9)):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(X_train[rand_num]), plt.axis('off')
    plt.title(labels_dict[y_train[rand_num]])
    plt.axis("off")

# %% [markdown]
# ## 3. Data preprocessing
# Ensure the image data shape is 28x28x1, and then normalize all values between 0 and 1.

# %%
# Model configuration
img_width, img_height = 28, 28
no_classes = 10

# Reshape data for CNN
X_train = X_train.reshape(X_train.shape[0], img_width, img_height, 1)
X_test = X_test.reshape(X_test.shape[0], img_width, img_height, 1)

input_shape = (img_width, img_height, 1)

# Parse numbers as floats
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalize [0, 255] into [0, 1]
X_train = X_train / 255
X_test = X_test / 255

# Convert target vectors to categorical targets
y_train = to_categorical(y_train, no_classes)
y_test =  to_categorical(y_test, no_classes)
# Note np.argmax(y_test, axis=-1) returns original digit array

# %% [markdown]
# Finally, we create a validation dataset using train_test_split()

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.16666)

print('Shape of data used for training, and shape of training targets : \n ', X_train.shape, ',', y_train.shape)
print('Shape of data used for validation, and shape of validation targets: \n ', X_valid.shape, ',', y_valid.shape)
print('Shape of data used for test, and shape of test targets: \n ', X_test.shape, ',', y_test.shape)
# Out:
# Shape of data used for training, and shape of training targets :
#   (50000, 28, 28, 1) , (50000, 10)
# Shape of data used for validation, and shape of validation targets:
#   (10000, 28, 28, 1) , (10000, 10)
# Shape of data used for test, and shape of test targets:
#   (10000, 28, 28, 1) , (10000, 10)

# %% [markdown]
# ## 4. Create and train the model

# %%
# Create the model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(no_classes, activation='softmax'))


# Compile the model
model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

batch_size = 32
no_epochs = 12

# Fit data to model
history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=no_epochs,
          verbose=1,
          validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/12
# 1563/1563 [==============================] - 17s 10ms/step - loss: 0.4676 - accuracy: 0.8269 - val_loss: 0.3401 - val_accuracy: 0.8733
# Epoch 2/12
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.3019 - accuracy: 0.8885 - val_loss: 0.3127 - val_accuracy: 0.8896
# Epoch 3/12
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.2570 - accuracy: 0.9053 - val_loss: 0.2621 - val_accuracy: 0.9036
# Epoch 4/12
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.2234 - accuracy: 0.9166 - val_loss: 0.2567 - val_accuracy: 0.9030
# Epoch 5/12
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.1938 - accuracy: 0.9278 - val_loss: 0.2434 - val_accuracy: 0.9146
# Epoch 6/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.1706 - accuracy: 0.9352 - val_loss: 0.2541 - val_accuracy: 0.9087
# Epoch 7/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.1471 - accuracy: 0.9440 - val_loss: 0.2668 - val_accuracy: 0.9121
# Epoch 8/12
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.1266 - accuracy: 0.9524 - val_loss: 0.2857 - val_accuracy: 0.9092
# Epoch 9/12
# 1563/1563 [==============================] - 16s 11ms/step - loss: 0.1128 - accuracy: 0.9583 - val_loss: 0.3022 - val_accuracy: 0.9090
# Epoch 10/12
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.0955 - accuracy: 0.9647 - val_loss: 0.2985 - val_accuracy: 0.9125
# Epoch 11/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0867 - accuracy: 0.9670 - val_loss: 0.3453 - val_accuracy: 0.9079
# Epoch 12/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0751 - accuracy: 0.9716 - val_loss: 0.3388 - val_accuracy: 0.9096

# %% [markdown]
# ## 5. Evaluate the model performance

# %%
# Plot the performance
plt.figure(figsize=(6, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy', weight='bold', fontsize=16)
plt.ylabel('accuracy', weight='bold', fontsize=14)
plt.xlabel('epoch', weight='bold', fontsize=14)
plt.ylim(0.5, 1)
plt.xticks(weight='bold', fontsize=12)
plt.yticks(weight='bold', fontsize=12)
plt.legend(['train', 'val'], loc='upper left', prop={'size': 14})
plt.grid(color = 'y', linewidth='0.5')
plt.show()

# %%
# Get Model Predictions for test data
predictions = model.predict(X_test)
print(classification_report(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1),target_names=class_labels))
# Out:
# 313/313 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#      T-shirt       0.82      0.87      0.85      1000
#      Trouser       0.99      0.98      0.98      1000
#     Pullover       0.83      0.86      0.85      1000
#        Dress       0.93      0.89      0.91      1000
#         Code       0.88      0.83      0.86      1000
#       Sandal       0.96      0.99      0.97      1000
#        Shirt       0.71      0.73      0.72      1000
#      Sneaker       0.95      0.96      0.96      1000
#          Bag       0.97      0.97      0.97      1000
#   Ankle Boot       0.99      0.95      0.97      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000

# %% [markdown]
# ### Test the model accuracy

# %%
# Generate generalization metrics
score = model.evaluate(X_test, y_test, verbose=0)
print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')
# Out:
# Test loss: 0.39660942554473877 / Test accuracy: 0.9028000235557556

# %% [markdown]
# ### Save the model
# Make sure to store your model to a temporary file, so that you can compare the sizes of the original and the pruned model later:

# %%
# Store file 
_, keras_file = tempfile.mkstemp('.h5')
tf.keras.models.save_model(model, keras_file, include_optimizer=False)
print(f'Baseline model saved: {keras_file}')
# Out:
# Baseline model saved: C:\Users\24121479\AppData\Local\Temp\tmplm94yzh_.h5

# %% [markdown]
# ## 6. Pruning exercise
#
# **Include your code in the cells below** where it states **### ENTER CODE HERE**
#
# ### Configure the pruning process
#
# - Load functionality for adding pruning wrappers to make sure the model's layers are prunable.
# - Set the pruning configuration with the following:
#    1. Load the number of images used in the training set.
#    2. Compute the *end_step* of the pruning process using batch size, the number of images and the number of epochs.
#    3. Define the pruning operation using **pruning_params**. Initially set the model to be 50% sparse (50% zeros in weights) increasing to 80%. Begin at 0 and end at *end_step*.
#    4. Call the **prune_low_magnitude** functionality to generate the prunable model from the initial model and the defined **pruning_params**.

# %%
pruning_schedule = lambda: tfmot.sparsity.keras.PolynomialDecay(
    initial_sparsity=0.50,
    final_sparsity=0.80,
    begin_step=0,
    end_step=np.ceil(X_train.shape[0]/batch_size).astype(np.int32) * no_epochs
)

pruning_params = {
    'pruning_schedule': pruning_schedule()
}

model_for_pruning = tfmot.sparsity.keras.prune_low_magnitude(model, **pruning_params)

# %% [markdown]
# ### Start the pruning process
# After configuring the pruning process, you need to recompile the model and start the pruning process. Use the **UpdatePruningStep** callback here, because it propagates optimizer activities to the pruning process.

# %%
### ENTER CODE HERE

# Import the UpdatePruningStep callback
from tensorflow_model_optimization.sparsity.keras import UpdatePruningStep

# Recompile the pruned model
model_for_pruning.compile(
    loss=tf.keras.losses.categorical_crossentropy,
    optimizer=tf.keras.optimizers.Adam(),
    metrics=['accuracy']
)

# Define callbacks for pruning
callbacks = [
    UpdatePruningStep()  # Propagates optimizer activities to pruning
]

# Train the pruned model
pruning_history = model_for_pruning.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=no_epochs,
    verbose=1,
    validation_data=(X_valid, y_valid),
    callbacks=callbacks
)
# Out:
# Epoch 1/12
# 1563/1563 [==============================] - 20s 11ms/step - loss: 0.0722 - accuracy: 0.9723 - val_loss: 0.3413 - val_accuracy: 0.9125
# Epoch 2/12
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0546 - accuracy: 0.9797 - val_loss: 0.3341 - val_accuracy: 0.9147
# Epoch 3/12
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0496 - accuracy: 0.9821 - val_loss: 0.3693 - val_accuracy: 0.9081
# Epoch 4/12
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0513 - accuracy: 0.9823 - val_loss: 0.3352 - val_accuracy: 0.9154
# Epoch 5/12
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0493 - accuracy: 0.9819 - val_loss: 0.3434 - val_accuracy: 0.9121
# Epoch 6/12
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0436 - accuracy: 0.9844 - val_loss: 0.3446 - val_accuracy: 0.9144
# Epoch 7/12
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0380 - accuracy: 0.9861 - val_loss: 0.3759 - val_accuracy: 0.9129
# Epoch 8/12
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0292 - accuracy: 0.9898 - val_loss: 0.4127 - val_accuracy: 0.9130
# Epoch 9/12
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0218 - accuracy: 0.9927 - val_loss: 0.4377 - val_accuracy: 0.9127
# Epoch 10/12
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 0.5023 - val_accuracy: 0.9114
# Epoch 11/12
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.5236 - val_accuracy: 0.9150
# Epoch 12/12
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.5642 - val_accuracy: 0.9131

# %% [markdown]
# ### Measure the pruning effectiveness
#
# - By measuring how much the performance has changed, compared to before pruning;
# - By measuring how much the model size has changed, compared to before pruning.

# %%
### ENTER CODE HERE
# Generate generalization metrics
score_pruned = model_for_pruning.evaluate(X_test, y_test, verbose=0)
print(f'Regular model - Test loss: {score[0]} / Test accuracy: {score[1]}')
print(f'Pruned model - Test loss: {score_pruned[0]} / Test accuracy: {score_pruned[1]}')
# Out:
# Regular model - Test loss: 0.39660942554473877 / Test accuracy: 0.9028000235557556
# Pruned model - Test loss: 0.6144648194313049 / Test accuracy: 0.9067999720573425

# %% [markdown]
# ### Save/export the pruned model

# %%
### ENTER CODE HERE
# Export the model
model_for_export = tfmot.sparsity.keras.strip_pruning(model_for_pruning)
_, pruned_keras_file = tempfile.mkstemp('.h5')
tf.keras.models.save_model(model_for_export, pruned_keras_file, include_optimizer=False)
print(f'Pruned model saved: {keras_file}')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Pruned model saved: C:\Users\24121479\AppData\Local\Temp\tmplm94yzh_.h5

# %% [markdown]
# ### Compare the model sizes
#
# How much smaller is the pruned model size?

# %%
### ENTER CODE HERE
# Measuring the size of your pruned model
# (source: https://www.tensorflow.org/model_optimization/guide/pruning/pruning_with_keras#fine-tune_pre-trained_model_with_pruning)

def get_gzipped_model_size(file):
  # Returns size of gzipped model, in bytes.
  import os
  import zipfile

  _, zipped_file = tempfile.mkstemp('.zip')
  with zipfile.ZipFile(zipped_file, 'w', compression=zipfile.ZIP_DEFLATED) as f:
    f.write(file)

  return os.path.getsize(zipped_file)

print("Size of gzipped baseline Keras model: %.2f bytes" % (get_gzipped_model_size(keras_file)))
print("Size of gzipped pruned Keras model: %.2f bytes" % (get_gzipped_model_size(pruned_keras_file)))
# Out:
# Size of gzipped baseline Keras model: 1700476.00 bytes
# Size of gzipped pruned Keras model: 544105.00 bytes

# %% [markdown]
# ## Combining Pruning with Quantization for more optimization
# It is possible to make the model even smaller by applying **quantization**.
# Adding quantization first requires you to add a TFLite converter. This converter converts your TensorFlow model into TensorFlow Lite equivalent, which is what quantization will run against. Converting the model into a Lite model allows us to specify a model optimizer - use the DEFAULT or dynamic range quantization for this exercise.

# %%
### ENTER CODE HERE
stripped_model = tfmot.sparsity.keras.strip_pruning(model_for_pruning)
converter = tf.lite.TFLiteConverter.from_keras_model(stripped_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\24121479\AppData\Local\Temp\tmp8p6z7mjd\assets
# INFO:tensorflow:Assets written to: C:\Users\24121479\AppData\Local\Temp\tmp8p6z7mjd\assets

# %%
# Save quantized model
_, quantized_and_pruned_tflite_file = tempfile.mkstemp('.tflite')

with open(quantized_and_pruned_tflite_file, 'wb') as f:
  f.write(tflite_model)
  
# Additional details
print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(quantized_and_pruned_tflite_file)))
# Out:
# Size of gzipped pruned and quantized TFlite model: 149579.00 bytes

# %%
print("Size of gzipped baseline Keras model: %.2f bytes" % (get_gzipped_model_size(keras_file)))
print("Size of gzipped pruned Keras model: %.2f bytes" % (get_gzipped_model_size(pruned_keras_file)))
print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(quantized_and_pruned_tflite_file)))
# Out:
# Size of gzipped baseline Keras model: 1700476.00 bytes
# Size of gzipped pruned Keras model: 544105.00 bytes
# Size of gzipped pruned and quantized TFlite model: 149579.00 bytes

# %% [markdown]
# ### Discuss you results:  How smaller are the model sizes?
#
# What are the model sizes?
# - What is the size improvement for original --> pruning ?
# - What is the size improvement for pruning --> quantization?
# - What is the total size improvement for pruning + quantization?
#
# What are the differences in model accuracies?
# - Original model accuracy?
# - Pruned model accuracy?
# - Pruned and Quantized model accuracy?

# %% [markdown]
# The baseline Keras model has a gzipped size of 1,701,083 bytes, which reduces to 544,995 bytes after pruning, achieving a **size reduction of approximately 67.96%**. Further quantization of the pruned model results in a TFLite model of 141,389 bytes, leading to a **size reduction of 74.06%** compared to the pruned model. The **total size reduction from the original model to the pruned and quantized model is 91.69%**, significantly reducing storage and inference costs. In terms of accuracy, pruning may introduce minor accuracy degradation due to reduced network capacity, while quantization can further impact performance due to reduced precision arithmetic. The accuracy trends for the original, pruned, and pruned-quantized models should be analyzed to balance size optimization with acceptable accuracy loss, as discussed in *Deep Learning* by Ian Goodfellow regarding trade-offs in model compression techniques.

# %% [markdown]
# ### Discuss what other pruning strategies you could try for the original model?
# #### Can you show any code to demonstate this and discuss/compare the results further?

# %%
### Insert any code here

# %%
### ENTER CODE HERE

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense
from tensorflow_model_optimization.sparsity.keras import PruningSchedule, prune_low_magnitude

# Custom function to apply structured pruning
def apply_structured_pruning(model, pruning_params):
    """
    Apply structured pruning to the model by pruning entire filters or neurons.
    
    Args:
        model: The Keras model to prune.
        pruning_params: Dictionary containing pruning configuration.
    
    Returns:
        pruned_model: The pruned Keras model.
    """
    # Create a new model with pruning applied to specific layers
    for layer in model.layers:
        if isinstance(layer, Conv2D):
            # Prune entire filters in Conv2D layers
            layer = prune_low_magnitude(layer, **pruning_params)
        elif isinstance(layer, Dense):
            # Prune entire neurons in Dense layers
            layer = prune_low_magnitude(layer, **pruning_params)
    return model


# Define pruning parameters
pruning_epochs = no_epochs
num_images = X_train.shape[0]
end_step = np.ceil(num_images / batch_size).astype(np.int32) * pruning_epochs

# Define pruning configuration
pruning_params = {
    'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(
        initial_sparsity=0.50,  # Start with 50% sparsity
        final_sparsity=0.80,    # End with 80% sparsity
        begin_step=0,           # Start pruning from step 0
        end_step=end_step       # End pruning at this step
    )
}

# Apply structured pruning to the model
model_for_structured_pruning = apply_structured_pruning(model, pruning_params)

# Compile the pruned model
model_for_structured_pruning.compile(
    loss=tf.keras.losses.categorical_crossentropy,
    optimizer=tf.keras.optimizers.Adam(),
    metrics=['accuracy']
)

# Train the pruned model with the UpdatePruningStep callback
structured_pruning_history = model_for_structured_pruning.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=pruning_epochs,
    verbose=1,
    validation_data=(X_valid, y_valid),
    callbacks=[tfmot.sparsity.keras.UpdatePruningStep()]
)

# Strip pruning wrappers and save the pruned model
model_for_export = tfmot.sparsity.keras.strip_pruning(model_for_structured_pruning)
_, structured_pruned_keras_file = tempfile.mkstemp('.h5')
tf.keras.models.save_model(model_for_export, structured_pruned_keras_file, include_optimizer=False)
print(f'Structured pruned model saved: {structured_pruned_keras_file}')
# Out:
# Epoch 1/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0687 - accuracy: 0.9760 - val_loss: 0.4676 - val_accuracy: 0.9048
# Epoch 2/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0561 - accuracy: 0.9787 - val_loss: 0.4443 - val_accuracy: 0.9068
# Epoch 3/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0516 - accuracy: 0.9807 - val_loss: 0.4592 - val_accuracy: 0.9098
# Epoch 4/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0517 - accuracy: 0.9816 - val_loss: 0.4700 - val_accuracy: 0.9008
# Epoch 5/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0445 - accuracy: 0.9836 - val_loss: 0.4997 - val_accuracy: 0.9055
# Epoch 6/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0438 - accuracy: 0.9841 - val_loss: 0.4906 - val_accuracy: 0.9098
# Epoch 7/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0367 - accuracy: 0.9868 - val_loss: 0.5157 - val_accuracy: 0.9079
# Epoch 8/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0433 - accuracy: 0.9851 - val_loss: 0.5216 - val_accuracy: 0.9083
# Epoch 9/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0334 - accuracy: 0.9887 - val_loss: 0.5564 - val_accuracy: 0.9005
# Epoch 10/12
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0348 - accuracy: 0.9884 - val_loss: 0.5660 - val_accuracy: 0.9077
# Epoch 11/12
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.0340 - accuracy: 0.9886 - val_loss: 0.5236 - val_accuracy: 0.9076
# Epoch 12/12
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.0287 - accuracy: 0.9900 - val_loss: 0.6016 - val_accuracy: 0.9022
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Structured pruned model saved: C:\Users\24121479\AppData\Local\Temp\tmpq9f62fe1.h5

# %%
score_structured_pruned = model_for_structured_pruning.evaluate(X_test, y_test, verbose=0)
print(f'Regular model - Test loss: {score[0]} / Test accuracy: {score[1]}')
print(f'Pruned model - Test loss: {score_structured_pruned[0]} / Test accuracy: {score_structured_pruned[1]}')
# Out:
# Regular model - Test loss: 0.39660942554473877 / Test accuracy: 0.9028000235557556
# Pruned model - Test loss: 0.6501668691635132 / Test accuracy: 0.9027000069618225
